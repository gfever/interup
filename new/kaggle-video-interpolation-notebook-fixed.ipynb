# %% [markdown]
# # Интерполяция видео до 60 FPS — блокнот для Kaggle
#
# Готовая последовательность ячеек для запуска на Kaggle (включите GPU и Internet):
# - Проверка окружения
# - Smoke‑test ffmpeg (2s)
# - Опционально: RIFE (DL)
# - Опционально: Real-ESRGAN (апскейл)
#
# Загрузите `dn.mp4` в `/kaggle/working/input/` перед запуском ячеек.

# %%
# Cell 1 — environment check (Python, torch, ffmpeg, nvidia)
import sys, subprocess, shutil
print('Python:', sys.version.split('\n')[0])
try:
    import torch
    print('torch:', torch.__version__)
    print('cuda available:', torch.cuda.is_available())
except Exception as e:
    print('torch import error:', e)
if shutil.which('ffmpeg'):
    p = subprocess.run(['ffmpeg', '-version'], stdout=subprocess.PIPE, text=True)
    print('ffmpeg:', p.stdout.splitlines()[0])
else:
    print('ffmpeg not found in PATH')
# nvidia-smi optional
try:
    p = subprocess.run(['nvidia-smi'], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print('nvidia-smi lines:', len(p.stdout.splitlines()))
except Exception as e:
    print('nvidia-smi not available:', e)
# Out:
# Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# torch: 2.6.0+cu124
# cuda available: True
# ffmpeg: ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# nvidia-smi lines: 24

# %%
# Ячейка 2 — параметры
# Automatically choose input from mounted Kaggle dataset, working input, or repository test.mp4
import os
# Paths to check (Kaggle datasets are usually mounted under /kaggle/input/<dataset-name>/)
KAGGLE_DATASET_PATH = '/kaggle/input/testmp4/test.mp4'
WORKING_INPUT_PATH = '/kaggle/working/input/test.mp4'
REPO_TEST_PATH = os.path.join(os.getcwd(), 'test.mp4')
OUTPUT_DIR = '/kaggle/working/output'
# Ensure working input and output directories exist
os.makedirs('/kaggle/working/input', exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)
# Select the first existing input file
if os.path.exists(KAGGLE_DATASET_PATH):
    INPUT = KAGGLE_DATASET_PATH
elif os.path.exists(WORKING_INPUT_PATH):
    INPUT = WORKING_INPUT_PATH
elif os.path.exists(REPO_TEST_PATH):
    INPUT = REPO_TEST_PATH
else:
    # Fallback to original default path
    INPUT = '/kaggle/working/input/dn.mp4'
print('INPUT =', INPUT)
print('OUTPUT_DIR =', OUTPUT_DIR)
# Out:
# INPUT = /kaggle/input/testmp4/test.mp4
# OUTPUT_DIR = /kaggle/working/output

# %%
# Ensure the selected INPUT is available at /kaggle/working/input/dn.mp4 so existing bash cells work
import shutil
selected_basename = 'dn.mp4'
target_path = '/kaggle/working/input/' + selected_basename
try:
    if os.path.exists(INPUT):
        # If target exists and points elsewhere, remove it first
        if os.path.islink(target_path) or os.path.exists(target_path):
            try:
                os.remove(target_path)
            except Exception:
                pass
        # Prefer symlink to avoid copying large files
        try:
            os.symlink(os.path.abspath(INPUT), target_path)
            print('Created symlink:', target_path, '->', INPUT)
        except Exception:
            shutil.copy2(INPUT, target_path)
            print('Copied', INPUT, 'to', target_path)
    else:
        print('Warning: selected INPUT does not exist:', INPUT)
except Exception as e:
    print('Error ensuring working input:', e)

# %%
# %%bash
# set -e
# echo 'Smoke-test: 2s minterpolate -> /kaggle/working/output/test_60_short.mp4'
# mkdir -p /kaggle/working/output
# # Use the working input copy/symlink created by the Python cell
# if [ ! -f /kaggle/working/input/dn.mp4 ]; then echo 'No input found at /kaggle/working/input/dn.mp4 — make sure the dataset is mounted or copied' >&2; exit 1; fi
# ffmpeg -y -t 2 -i /kaggle/working/input/dn.mp4 -vf "minterpolate=mi_mode=mci:mc_mode=aobmc:vsbmc=1:fps=60" -c:v libx264 -preset veryfast -crf 20 /kaggle/working/output/test_60_short.mp4
# ls -lh /kaggle/working/output/test_60_short.mp4 || true
# Out:
# Smoke-test: 2s minterpolate -> /kaggle/working/output/test_60_short.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/testmp4/test.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#     comment         : Signature: YUuyPyfmpX3m0xuCLFNFr1KFbrrZG+FIcln31c7Y0QtjIwrLxwWGFkCO4ufz2L6lZLI2WBJyX0mmMXsDMDp0fjrDqLTOwDQRTWINsyuqkaLRsZlN2+yZaSWbhXnaD8eb+o7y9LM6ihQKW889jRNsEEzleB/NiB1ot/pidjvjr+Q=
#   Duration: 00:00:06.04, start: 0.000000, bitrate: 1010 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 640x480, 875 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5aae817cf180] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5aae817cf180] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5aae817cf180] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=6 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=20.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/kaggle/working/output/test_60_short.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Signature: YUuyPyfmpX3m0xuCLFNFr1KFbrrZG+FIcln31c7Y0QtjIwrLxwWGFkCO4ufz2L6lZLI2WBJyX0mmMXsDMDp0fjrDqLTOwDQRTWINsyuqkaLRsZlN2+yZaSWbhXnaD8eb+o7y9LM6ihQKW889jRNsEEzleB/NiB1ot/pidjvjr+Q=
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 60 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.418  pts=0.418
#   size=376
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.441  pts=0.441
#   size=372
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.458  pts=0.667
#   size=10664
# [h264 @ 0x5aae81851880] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.464  pts=0.464
#   size=368
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)eed=0.326x
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.488  pts=0.488
#   size=353
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.500  pts=0.583
#   size=5598
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.511  pts=0.511
#   size=366
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.534  pts=0.534
#   size=367
# cur_dts is invalid st:0 (0) [init:1 i_done:0 finish:0] (this is harmless if it occurs once at the start per stream)
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.542  pts=0.542
#   size=2863
# [h264 @ 0x5aae817f3680] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=   0 QP=19.82 NAL=3 Slice:I Poc:0   I:1200 P:0    SKIP:0    size=7580 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.557  pts=0.557
#   size=386
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.580  pts=0.580
#   size=367
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.583  pts=0.625
#   size=4058
# [h264 @ 0x5aae817d63c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=   1 QP=19.47 NAL=2 Slice:P Poc:8   I:748  P:317  SKIP:135  size=5832 bytes
# [libx264 @ 0x5aae817cf180] frame=   2 QP=20.93 NAL=2 Slice:B Poc:4   I:37   P:531  SKIP:632  size=1720 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.604  pts=0.604
#   size=370
# stream #0:3 fps= 12 q=28.0 10000000000000000000000000001000size=       0kB time=00:00:00.55 bitrate=   0.7kbits/s speed=0.295x
#   keyframe=0
#   duration=0.042
#   dts=0.625  pts=0.833
#   size=11078
# [h264 @ 0x5aae817e3240] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=   3 QP=21.65 NAL=0 Slice:B Poc:2   I:20   P:235  SKIP:945  size=913 bytes
# [libx264 @ 0x5aae817cf180] frame=   4 QP=21.13 NAL=0 Slice:B Poc:6   I:14   P:215  SKIP:971  size=726 bytes
# [libx264 @ 0x5aae817cf180] frame=   5 QP=20.28 NAL=2 Slice:P Poc:16  I:415  P:314  SKIP:471  size=4678 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.627  pts=0.627
#   size=365
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.650  pts=0.650
#   size=317
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.667  pts=0.750
#   size=5424
# [h264 @ 0x5aae81851880] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=   6 QP=21.55 NAL=2 Slice:B Poc:12  I:22   P:309  SKIP:869  size=1297 bytes
# [libx264 @ 0x5aae817cf180] frame=   7 QP=22.84 NAL=0 Slice:B Poc:10  I:15   P:189  SKIP:996  size=741 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.673  pts=0.673
#   size=389
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.697  pts=0.697
#   size=358
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.708  pts=0.708
#   size=3499
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=   8 QP=22.80 NAL=0 Slice:B Poc:14  I:8    P:242  SKIP:950  size=703 bytes
# [libx264 @ 0x5aae817cf180] frame=   9 QP=20.78 NAL=2 Slice:P Poc:24  I:573  P:359  SKIP:268  size=5244 bytes
# [libx264 @ 0x5aae817cf180] frame=  10 QP=21.26 NAL=2 Slice:B Poc:20  I:152  P:567  SKIP:481  size=2453 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.720  pts=0.720
#   size=385
# stream #1:1 fps= 13 q=28.0 10000000000000000000000000001000size=       0kB time=00:00:00.67 bitrate=   0.6kbits/s speed=0.273x
#   keyframe=1
#   duration=0.023
#   dts=0.743  pts=0.743
#   size=402
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.750  pts=0.792
#   size=2997
# [h264 @ 0x5aae817f3680] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  11 QP=24.28 NAL=0 Slice:B Poc:18  I:10   P:317  SKIP:873  size=853 bytes
# [libx264 @ 0x5aae817cf180] frame=  12 QP=24.23 NAL=0 Slice:B Poc:22  I:9    P:294  SKIP:897  size=879 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.766  pts=0.766
#   size=382
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.789  pts=0.789
#   size=341
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.792  pts=0.917
#   size=6725
# [h264 @ 0x5aae817d63c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  13 QP=20.35 NAL=2 Slice:P Poc:30  I:483  P:409  SKIP:308  size=4471 bytes
# [libx264 @ 0x5aae817cf180] frame=  14 QP=23.98 NAL=2 Slice:B Poc:26  I:21   P:278  SKIP:901  size=961 bytes
# [libx264 @ 0x5aae817cf180] frame=  15 QP=23.95 NAL=0 Slice:B Poc:28  I:15   P:313  SKIP:872  size=857 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.813  pts=0.813
#   size=378
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.833  pts=0.875
#   size=2247
# [h264 @ 0x5aae817e3240] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  16 QP=20.51 NAL=2 Slice:P Poc:38  I:612  P:433  SKIP:155  size=5869 bytes
# [libx264 @ 0x5aae817cf180] frame=  17 QP=22.69 NAL=2 Slice:B Poc:34  I:58   P:518  SKIP:624  size=2002 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.836  pts=0.836
#   size=375
# stream #1:8 fps= 12 q=28.0 10000000000000000000000000002000size=       0kB time=00:00:00.78 bitrate=   0.5kbits/s speed=0.258x
#   keyframe=1
#   duration=0.023
#   dts=0.859  pts=0.859
#   size=388
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.875  pts=1.083
#   size=9347
# [h264 @ 0x5aae81851880] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  18 QP=24.32 NAL=0 Slice:B Poc:32  I:20   P:398  SKIP:782  size=1484 bytes
# [libx264 @ 0x5aae817cf180] frame=  19 QP=24.39 NAL=0 Slice:B Poc:36  I:16   P:326  SKIP:858  size=840 bytes
# [libx264 @ 0x5aae817cf180] frame=  20 QP=21.26 NAL=2 Slice:P Poc:46  I:308  P:469  SKIP:423  size=3418 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.882  pts=0.882
#   size=377
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.906  pts=0.906
#   size=376
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.917  pts=1.000
#   size=5143
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  21 QP=23.10 NAL=2 Slice:B Poc:42  I:20   P:367  SKIP:813  size=1083 bytes
# [libx264 @ 0x5aae817cf180] frame=  22 QP=24.99 NAL=0 Slice:B Poc:40  I:9    P:198  SKIP:993  size=577 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.929  pts=0.929
#   size=325
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.952  pts=0.952
#   size=362
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=0.958  pts=0.958
#   size=2947
# [h264 @ 0x5aae817f3680] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  23 QP=24.39 NAL=0 Slice:B Poc:44  I:7    P:264  SKIP:929  size=589 bytes
# [libx264 @ 0x5aae817cf180] frame=  24 QP=21.11 NAL=2 Slice:P Poc:54  I:418  P:513  SKIP:269  size=3999 bytes
# [libx264 @ 0x5aae817cf180] frame=  25 QP=21.81 NAL=2 Slice:B Poc:50  I:93   P:531  SKIP:576  size=1698 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=0.975  pts=0.975
#   size=351
# stream #1:6 fps= 13 q=28.0 10000000000000000000000000002000size=       0kB time=00:00:00.92 bitrate=   0.4kbits/s speed=0.256x
#   keyframe=1
#   duration=0.023
#   dts=0.998  pts=0.998
#   size=368
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.000  pts=1.042
#   size=2516
# [h264 @ 0x5aae817d63c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  26 QP=24.40 NAL=0 Slice:B Poc:48  I:9    P:229  SKIP:962  size=560 bytes
# [libx264 @ 0x5aae817cf180] frame=  27 QP=23.30 NAL=0 Slice:B Poc:52  I:7    P:278  SKIP:915  size=667 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.022  pts=1.022
#   size=384
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.042  pts=1.250
#   size=11835
# [h264 @ 0x5aae817e3240] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  28 QP=21.35 NAL=2 Slice:P Poc:62  I:323  P:472  SKIP:405  size=3093 bytes
# [libx264 @ 0x5aae817cf180] frame=  29 QP=23.06 NAL=2 Slice:B Poc:58  I:16   P:356  SKIP:828  size=967 bytes
# [libx264 @ 0x5aae817cf180] frame=  30 QP=23.22 NAL=0 Slice:B Poc:56  I:2    P:161  SKIP:1037 size=358 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.045  pts=1.045
#   size=389
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.068  pts=1.068
#   size=377
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.083  pts=1.167
#   size=5163
# [h264 @ 0x5aae81851880] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  31 QP=25.69 NAL=0 Slice:B Poc:60  I:5    P:108  SKIP:1087 size=298 bytes
# [libx264 @ 0x5aae817cf180] frame=  32 QP=21.51 NAL=2 Slice:P Poc:70  I:395  P:524  SKIP:281  size=3666 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.091  pts=1.091
#   size=390
# stream #1:3 fps= 13 q=28.0 10000000000000000000000000002000size=       0kB time=00:00:01.04 bitrate=   0.4kbits/s speed=0.248x
#   keyframe=1
#   duration=0.023
#   dts=1.115  pts=1.115
#   size=379
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.125  pts=1.125
#   size=3205
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  33 QP=22.42 NAL=2 Slice:B Poc:66  I:39   P:434  SKIP:727  size=1250 bytes
# [libx264 @ 0x5aae817cf180] frame=  34 QP=24.15 NAL=0 Slice:B Poc:64  I:2    P:217  SKIP:981  size=478 bytes
# [libx264 @ 0x5aae817cf180] frame=  35 QP=25.42 NAL=0 Slice:B Poc:68  I:2    P:262  SKIP:936  size=635 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.138  pts=1.138
#   size=392
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.161  pts=1.161
#   size=370
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.167  pts=1.208
#   size=2365
# [h264 @ 0x5aae817f3680] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  36 QP=20.64 NAL=2 Slice:P Poc:78  I:572  P:470  SKIP:158  size=5085 bytes
# [libx264 @ 0x5aae817cf180] frame=  37 QP=22.76 NAL=2 Slice:B Poc:74  I:55   P:542  SKIP:603  size=1790 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.184  pts=1.184
#   size=386
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.207  pts=1.207
#   size=385
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.208  pts=1.417
#   size=7831
# [h264 @ 0x5aae817d63c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  38 QP=24.99 NAL=0 Slice:B Poc:72  I:18   P:318  SKIP:864  size=1030 bytes
# [libx264 @ 0x5aae817cf180] frame=  39 QP=24.56 NAL=0 Slice:B Poc:76  I:11   P:262  SKIP:927  size=714 bytes
# [libx264 @ 0x5aae817cf180] frame=  40 QP=20.97 NAL=2 Slice:P Poc:86  I:384  P:488  SKIP:328  size=3677 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.231  pts=1.231
#   size=366
# stream #0:1 fps= 13 q=28.0 10000000000000000000000000002000size=       0kB time=00:00:01.18 bitrate=   0.3kbits/s speed=0.248x
#   keyframe=0
#   duration=0.042
#   dts=1.250  pts=1.333
#   size=4060
# [h264 @ 0x5aae817e3240] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  41 QP=22.78 NAL=2 Slice:B Poc:82  I:21   P:360  SKIP:819  size=1185 bytes
# [libx264 @ 0x5aae817cf180] frame=  42 QP=23.31 NAL=0 Slice:B Poc:80  I:9    P:205  SKIP:986  size=564 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.254  pts=1.254
#   size=365
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.277  pts=1.277
#   size=367
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.292  pts=1.292
#   size=2402
# [h264 @ 0x5aae81851880] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  43 QP=24.74 NAL=0 Slice:B Poc:84  I:7    P:318  SKIP:875  size=717 bytes
# [libx264 @ 0x5aae817cf180] frame=  44 QP=19.98 NAL=2 Slice:P Poc:94  I:552  P:449  SKIP:199  size=4956 bytes
# [libx264 @ 0x5aae817cf180] frame=  45 QP=21.62 NAL=2 Slice:B Poc:90  I:65   P:538  SKIP:597  size=1973 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.300  pts=1.300
#   size=370
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.324  pts=1.324
#   size=367
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.333  pts=1.375
#   size=2077
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  46 QP=24.15 NAL=0 Slice:B Poc:88  I:7    P:214  SKIP:979  size=606 bytes
# [libx264 @ 0x5aae817cf180] frame=  47 QP=22.87 NAL=0 Slice:B Poc:92  I:17   P:299  SKIP:884  size=957 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.347  pts=1.347
#   size=365
# stream #1:8 fps= 13 q=28.0 10000000000000000000000000003000size=       0kB time=00:00:01.30 bitrate=   0.3kbits/s speed=0.243x
#   keyframe=1
#   duration=0.023
#   dts=1.370  pts=1.370
#   size=373
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.375  pts=1.583
#   size=9162
# [h264 @ 0x5aae817f3680] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  48 QP=20.10 NAL=2 Slice:P Poc:102 I:290  P:408  SKIP:502  size=2994 bytes
# [libx264 @ 0x5aae817cf180] frame=  49 QP=21.80 NAL=2 Slice:B Poc:98  I:20   P:371  SKIP:809  size=1017 bytes
# [libx264 @ 0x5aae817cf180] frame=  50 QP=22.76 NAL=0 Slice:B Poc:96  I:6    P:178  SKIP:1016 size=449 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.393  pts=1.393
#   size=363
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.416  pts=1.416
#   size=346
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.417  pts=1.500
#   size=4965
# [h264 @ 0x5aae817d63c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  51 QP=23.90 NAL=0 Slice:B Poc:100 I:9    P:97   SKIP:1094 size=306 bytes
# [libx264 @ 0x5aae817cf180] frame=  52 QP=19.66 NAL=2 Slice:P Poc:110 I:389  P:418  SKIP:393  size=2910 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.440  pts=1.440
#   size=368
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.458  pts=1.458
#   size=2761
# [h264 @ 0x5aae817e3240] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  53 QP=21.03 NAL=2 Slice:B Poc:106 I:25   P:336  SKIP:839  size=878 bytes
# [libx264 @ 0x5aae817cf180] frame=  54 QP=23.55 NAL=0 Slice:B Poc:104 I:9    P:173  SKIP:1018 size=380 bytes
# [libx264 @ 0x5aae817cf180] frame=  55 QP=23.45 NAL=0 Slice:B Poc:108 I:3    P:141  SKIP:1056 size=318 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.463  pts=1.463
#   size=349
# stream #1:6 fps= 13 q=28.0 10000000000000000000000000003000size=       0kB time=00:00:01.41 bitrate=   0.3kbits/s speed=0.24x
#   keyframe=1
#   duration=0.023
#   dts=1.486  pts=1.486
#   size=356
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.500  pts=1.542
#   size=2576
# [h264 @ 0x5aae81851880] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  56 QP=19.86 NAL=2 Slice:P Poc:118 I:408  P:463  SKIP:329  size=3781 bytes
# [libx264 @ 0x5aae817cf180] frame=  57 QP=22.00 NAL=2 Slice:B Poc:114 I:39   P:381  SKIP:780  size=1246 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.509  pts=1.509
#   size=379
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.533  pts=1.533
#   size=372
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.542  pts=1.750
#   size=9539
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  58 QP=22.92 NAL=0 Slice:B Poc:112 I:13   P:218  SKIP:969  size=750 bytes
# [libx264 @ 0x5aae817cf180] frame=  59 QP=22.78 NAL=0 Slice:B Poc:116 I:7    P:172  SKIP:1021 size=482 bytes
# [libx264 @ 0x5aae817cf180] frame=  60 QP=19.90 NAL=2 Slice:P Poc:126 I:336  P:398  SKIP:466  size=3033 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.556  pts=1.556
#   size=371
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.579  pts=1.579
#   size=380
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.583  pts=1.667
#   size=4740
# [h264 @ 0x5aae817f3680] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  61 QP=22.27 NAL=2 Slice:B Poc:122 I:16   P:298  SKIP:886  size=933 bytes
# [libx264 @ 0x5aae817cf180] frame=  62 QP=23.75 NAL=0 Slice:B Poc:120 I:3    P:105  SKIP:1092 size=330 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.602  pts=1.602
#   size=389
# stream #0:3 fps= 13 q=28.0 size=       0kB time=00:00:01.55 bitrate=   0.2kbits/s speed=0.241x
#   keyframe=0
#   duration=0.042
#   dts=1.625  pts=1.625
#   size=2951
# [h264 @ 0x5aae817d63c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  63 QP=23.01 NAL=0 Slice:B Poc:124 I:8    P:202  SKIP:990  size=521 bytes
# [libx264 @ 0x5aae817cf180] frame=  64 QP=20.19 NAL=2 Slice:P Poc:134 I:459  P:393  SKIP:348  size=4652 bytes
# [libx264 @ 0x5aae817cf180] frame=  65 QP=21.20 NAL=2 Slice:B Poc:130 I:75   P:531  SKIP:594  size=1809 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.625  pts=1.625
#   size=377
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.649  pts=1.649
#   size=363
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.667  pts=1.708
#   size=2345
# [h264 @ 0x5aae817e3240] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  66 QP=21.67 NAL=0 Slice:B Poc:128 I:12   P:214  SKIP:974  size=629 bytes
# [libx264 @ 0x5aae817cf180] frame=  67 QP=23.13 NAL=0 Slice:B Poc:132 I:16   P:301  SKIP:883  size=966 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.672  pts=1.672
#   size=382
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.695  pts=1.695
#   size=381
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.708  pts=1.917
#   size=8277
# [h264 @ 0x5aae81851880] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  68 QP=20.19 NAL=2 Slice:P Poc:140 I:340  P:485  SKIP:375  size=3710 bytes
# [libx264 @ 0x5aae817cf180] frame=  69 QP=23.55 NAL=2 Slice:B Poc:136 I:11   P:209  SKIP:980  size=659 bytes
# [libx264 @ 0x5aae817cf180] frame=  70 QP=23.99 NAL=0 Slice:B Poc:138 I:7    P:230  SKIP:963  size=588 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.718  pts=1.718
#   size=369
# stream #1:1 fps= 13 q=28.0 size=       0kB time=00:00:01.67 bitrate=   0.2kbits/s speed=0.236x
#   keyframe=1
#   duration=0.023
#   dts=1.741  pts=1.741
#   size=386
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.750  pts=1.833
#   size=3913
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  71 QP=20.38 NAL=2 Slice:P Poc:148 I:420  P:449  SKIP:331  size=3942 bytes
# [libx264 @ 0x5aae817cf180] frame=  72 QP=20.90 NAL=2 Slice:B Poc:144 I:25   P:370  SKIP:805  size=1075 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.765  pts=1.765
#   size=375
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.788  pts=1.788
#   size=384
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.792  pts=1.792
#   size=2215
# [h264 @ 0x5aae817f3680] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  73 QP=24.22 NAL=0 Slice:B Poc:142 I:13   P:231  SKIP:956  size=635 bytes
# [libx264 @ 0x5aae817cf180] frame=  74 QP=23.42 NAL=0 Slice:B Poc:146 I:6    P:184  SKIP:1010 size=446 bytes
# [libx264 @ 0x5aae817cf180] frame=  75 QP=20.91 NAL=2 Slice:P Poc:156 I:333  P:505  SKIP:362  size=3653 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.811  pts=1.811
#   size=356
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.833  pts=1.875
#   size=1757
# [h264 @ 0x5aae817d63c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [libx264 @ 0x5aae817cf180] frame=  76 QP=23.33 NAL=2 Slice:B Poc:152 I:14   P:340  SKIP:846  size=970 bytes
# [libx264 @ 0x5aae817cf180] frame=  77 QP=25.51 NAL=0 Slice:B Poc:150 I:8    P:169  SKIP:1023 size=442 bytes
# stream #1:
#   keyframe=1
#   duration=0.023
#   dts=1.834  pts=1.834
#   size=377
# 00000000  21 1a cc 5f df ff c0 00 b0 85 b2 14 88 86 63 4d !.._..........cM
# 00000010  f9 ea 4e 33 9b e2 f2 f2 d7 22 89 54 ac c9 49 25 ..N3.....".T..I%
# 00000020  25 8e c6 7d a5 ef 5b 63 e7 2a b0 18 f2 ef 3c 3d %..}..[c.*....<=
# 00000030  6c d5 12 37 d5 aa 2c 02 d9 40 fd fd 02 4c 7a bd l..7..,..@...Lz.
# 00000040  61 5b ad 04 05 51 44 cc 04 b9 76 6c 40 42 c6 52 a[...QD...vl@B.R
# 00000050  3e 7f 3a 75 6a a5 0d 62 9b ea f7 da d2 c2 f4 78 >.:uj..b.......x
# 00000060  de e1 2f f4 90 36 30 79 00 e8 44 bb d8 95 63 3c ../..60y..D...c<
# 00000070  6f e3 09 59 e0 a1 6d 95 ac bc 13 02 e2 bc 4d be o..Y..m.......M.
# 00000080  e8 e8 3e bd d1 1f 9b 2b 97 a6 21 85 d4 dd d2 1e ..>....+..!.....
# 00000090  0f 7f 02 96 91 5a ed be ba 0e a4 99 2f a9 18 45 .....Z....../..E
# 000000a0  ec d2 ee d1 1b ec 89 82 f0 87 8c 0d 6e 02 1b 7e ............n..~
# 000000b0  a2 8d 7f 74 52 c2 f9 e4 2a 73 ad cc b7 b2 ab 78 ...tR...*s.....x
# 000000c0  5e b6 50 6f 38 d8 e6 71 6b 8c e7 7d a4 d2 28 bc ^.Po8..qk..}..(.
# 000000d0  d5 a4 b0 f9 01 11 f6 d8 f4 a4 c1 42 2e 53 83 9b ...........B.S..
# 000000e0  c9 8d 76 4b 45 73 0f b7 af ab bb b2 49 eb 27 4b ..vKEs......I.'K
# 000000f0  bb 2a 54 b2 d2 94 91 1c e3 1b 84 6f 78 10 05 3b .*T........ox..;
# 00000100  81 52 c2 95 07 51 a2 7d cf 3c f0 ea 4e 33 9b e3 .R...Q.}.<..N3..
# 00000110  5b bc b5 c8 a2 55 4a 86 58 a2 04 ae 80 a3 aa 4c [....UJ.X......L
# 00000120  8a 86 f2 f5 5f 38 aa 34 b5 24 d2 5d bc 31 38 ec ...._8.4.$.].18.
# 00000130  dd 29 54 42 0e 6e 8e 2b 9a 83 00 8c 69 1b 96 5c .)TB.n.+....i..\
# 00000140  bb 18 a4 fe bd 4b 39 f9 ff 90 de 3e 95 85 9a af .....K9....>....
# 00000150  c4 02 a9 9a 91 37 db 31 2d 6b 59 67 d6 08 ab e7 .....7.1-kYg....
# 00000160  e3 52 88 b5 54 af 1d a7 97 6c 6b 06 bc 71 68 88 .R..T....lk..qh.
# 00000170  35 d7 45 bd fe 2f 4e 67 c0                      5.E../Ng.
# stream #1:8 fps= 13 q=28.0 10000000000000000000000000003000size=       0kB time=00:00:01.78 bitrate=   0.2kbits/s speed=0.233x
#   keyframe=1
#   duration=0.023
#   dts=1.858  pts=1.858
#   size=375
# 00000000  21 1a cc 0e de 7f c0 00 af 88 39 10 a6 36 7b ef !.........9..6{.
# 00000010  f6 3f 18 eb 9a eb 3a cb ce 37 ab 4a 85 51 bc 5e .?....:..7.J.Q.^
# 00000020  44 95 a8 2c 38 f7 a7 69 ea f8 b4 7e 08 76 a4 eb D..,8..i...~.v..
# 00000030  2d 0f 8e 15 19 c4 3f 2b 14 ee 74 c3 2c 4f 03 7d -.....?+..t.,O.}
# 00000040  9d 4d 95 3b e6 0b 53 96 e8 c7 3c 51 6d 5d 9d e1 .M.;..S...<Qm]..
# 00000050  37 5e 1e 89 5c 7d 96 fe 70 42 d4 b6 d3 0d ca cd 7^..\}..pB......
# 00000060  9a cb 55 8f 8c 42 e5 e6 5b e8 ae 4a bb dd 0b 56 ..U..B..[..J...V
# 00000070  53 d7 e4 fd 53 84 58 90 ac 64 07 00 02 74 12 ac S...S.X..d...t..
# 00000080  48 31 4d c4 2d 00 bc 51 22 20 10 02 aa 5e 22 fa H1M.-..Q" ...^".
# 00000090  1e d2 10 db 0a 11 2b ae 11 01 04 47 25 85 ac 6e ......+....G%..n
# 000000a0  28 05 a6 49 18 a6 91 d6 ec 11 8d a0 b1 49 68 33 (..I.........Ih3
# 000000b0  77 82 b9 6c 5a d5 26 03 9a 1a 79 20 5f 3a 5e f7 w..lZ.&...y _:^.
# 000000c0  38 ae 2c 81 34 92 31 a8 26 aa bb ea 98 4f 60 99 8.,.4.1.&....O`.
# 000000d0  22 43 5a d3 5a d5 a2 d3 44 45 67 0a e0 e0 95 9d "CZ.Z...DEg.....
# 000000e0  54 1f 71 55 b1 6a 8b ee df 1b ea 09 0d ab aa ca T.qU.j..........
# 000000f0  c6 0e 63 9a 09 d2 b1 78 69 80 12 b0 2a 08 0d 23 ..c....xi...*..#
# 00000100  06 a2 be 20 c5 44 7b 97 29 fe 3d dd 73 c3 3d b9 ... .D{.).=.s.=.
# 00000110  bc e1 64 a8 55 09 44 55 e5 d0 f2 11 2e ed 3b a6 ..d.U.DU......;.
# 00000120  ae 2a ad 37 a8 56 55 4a 66 2e a7 74 e8 8f dd 3f .*.7.VUJf..t...?
# 00000130  9a 65 a4 05 69 9f 21 94 5e 8e 9c f7 2b 44 d1 e2 .e..i.!.^...+D..
# 00000140  8f c2 6b a0 c0 ae ef d0 80 80 c3 e7 31 16 25 e0 ..k.........1.%.
# 00000150  42 5c 8e 34 d5 de 93 87 b7 1a 9b 3d 74 0a 09 4f B\.4.......=t..O
# 00000160  a3 40 a2 38 0b b1 e8 3e 0b cd 56 58 ea ad 36 ff .@.8...>..VX..6.
# 00000170  c8 50 e1 e7 31 4e bf                            .P..1N.
# stream #0:
#   keyframe=0
#   duration=0.042
#   dts=1.875  pts=2.083
#   size=8807
# 00000000  00 00 03 34 41 9b 32 49 a8 41 6c 99 4c 08 45 ff ...4A.2I.Al.L.E.
# 00000010  fe 6d ac 4d 0e 36 2b d0 37 94 05 dc 56 e2 af 3b .m.M.6+.7...V..;
# 00000d80  3e f2 1d 96 b6 c9 22 3d 86 6e 67 9d 4c 8a cb 85 >....."=.ng.L...
# 00000d90  68 fa 88 55 2e 5f b2 c3 e4 cb 45 01 39 78 48 52 h..U._....E.9xHR
# 00000da0  bf 60 ef 2e 9d eb cb 6e 75 dc 5e 5a 36 35 16 97 .`.....nu.^Z65..
# 00000db0  38 f5 01 b3 f5 f1 6a b5 ae c3 ac 59 9b 4a f0 67 8.....j....Y.J.g
# 00000dc0  30 19 95 15 f7 99 1b c5 3e fc 47 7a 7a 8e 7c 6d 0.......>.Gzz.|m
# 00000dd0  f0 09 c9 8a 27 ce 9f e5 78 a0 f5 86 cf 0d 43 f7 ....'...x.....C.
# 00000de0  cd d4 9b 8e 10 21 d3 dc d3 7c d1 5b a8 e9 13 ff .....!...|.[....
# 00000df0  8c 4e db 69 8f af 1f cb e3 4e 40 f3 a2 77 f8 30 .N.i.....N@..w.0
# 00000e00  15 3c 91 27 b2 06 24 91 94 5a 75 24 39 14 99 64 .<.'..$..Zu$9..d
# 00000e10  0a 57 b0 1f 22 d6 50 a8 25 f3 6c b9 aa e4 5f 86 .W..".P.%.l..._.
# 00000e20  24 e6 6e b4 0b 62 b6 fd 9e d2 57 ff 7d fb 85 46 $.n..b....W.}..F
# 00000e30  5e ef b8 2e a8 5a 0a 43 3c 65 eb dc 9e 84 27 4c ^....Z.C<e....'L
# 00000e40  33 f6 0d f4 7a b2 67 03 85 24 e4 06 22 04 7f 78 3...z.g..$.."..x
# 00000e50  41 fd b0 fa b0 21 0d 5e 3b b1 ea 62 ab 48 db 34 A....!.^;..b.H.4
# 00000e60  67 8a c6 13 d2 4f f5 23 4a 7c 48 55 fa ec da 2b g....O.#J|HU...+
# ...
# 000000b0  e1 d6 2c 4a 38 0c 7c 65 ed b9 e5 3d 15 8d 06 16 ..,J8.|e...=....
# 000000c0  e2 d6 59 b9 0b 5c 26 a3 64 17 31 10 45 e6 db 50 ..Y..\&.d.1.E..P
# 000000d0  a5 92 e7 26 d3 e6 ba 56 3d 13 3a 45 9a e6 89 c3 ...&...V=.:E....
# 000000e0  26 25 33 30 68 d2 32 26 9b 80 f6 d6 38 c9 ea 0b &%30h.2&....8...
# 000000f0  3d ae aa ee b8 03 93 4a e1 0b d1 62 e0 b7 2f 35 =......J...b../5
# 00000100  7e 71 c4 ef 4d a4 71 d8 c1 9e ac 0c e4 80 cb 24 ~q..M.q........$
# 00000110  d5 88 3c 09 90 75 1b e5 4b 62 a1 32 33 87 b4 55 ..<..u..Kb.23..U
# 00000120  27 b9 a7 d5 dc 27 bb c8 45 ea 5f 7b 68 6c c3 9a '....'..E._{hl..
# 00000130  42 d0 6b 08 d5 c1 0c 18 ea fe 32 5d 2e 9f 08 7a B.k.......2]...z
# 00000140  c7 48 28 60 42 20 01 42 c1 df dc 04 d2 e9 b5 12 .H(`B .B........
# 00000150  9d ff 79 5d d5 50 9b 88 32 0e 54 02 23 3e 6f 74 ..y].P..2.T.#>ot
# 00000160  07 17 9d 42 2c 83 31 ca 70 91 b1 b9 6c cb bc 84 ...B,.1.p...l...
# 000004d0  6d e5 a9 2e e2 fc 7e 1f 47 3a 65 ce fa a4 7c 03 m.....~.G:e...|.
# 000004e0  ce b6 4e a0 fd 95 ee 3e 30 48 cd e8 c2 5c 37 0f ..N....>0H...\7.
# 000004f0  e9 18 b1 3b 57 02 b2 5b eb 24 94 18 be 4e 61 5a ...;W..[.$...NaZ
# 00000500  ef 34 42 12 d6 e8 aa f3 0d 82 17 12 84 e7 ae be .4B.............
# 00000510  d8 88 24 fc 13 58 40 c7 6b 9a e0 41 7f 42 1f 96 ..$..X@.k..A.B..
# 00000520  a1 57 d7 68 ff d3 a2 a1 2e a2 47 d6 40 14 6e c9 .W.h......G.@.n.
# 00000530  a0 97 5f 0b 98 0a 7b 08 6b 4b 4f 42 ad 48 6e 45 .._...{.kKOB.HnE
# 00000540  7e 2a a8 f2 eb 82 ec d3 e5 b5 f2 8f 01 ef 0b fa ~*..............
# 00000550  87 a5 c7 25 41 ab 93 6c c0 2b e6 2a 08 00 33 78 ...%A..l.+.*..3x
# 00000560  1a fc 25 08 ab 0c 99 ff e1 38 b8 85 82 a1 47 8c ..%......8....G.
# 00000570  c4 05 a2 52 0d ae de 40 cf e4 6c 42 7a 29 0e 63 ...R...@..lBz).c
# 00000580  8d ad e8 e7 71 1b 87 d5 c4 be f8 d8 af e9 35 79 ....q.........5y
# 00000590  f3 b9 41 64 09 03 7b f3 26 bf 80 dc fa d5 fc c9 ..Ad..{.&.......
# 000005a0  28 e8 bc 6d ff 97 80 22 15 7f 0c 28 e6 a1 b2 35 (..m..."...(...5
# 000005b0  e3 f4 41 8f 98 eb ae fb 34 90 b9 64 08 bb 8c f6 ..A.....4..d....
# 000005c0  90 bc dd 60 f0 fd 74 29 db 48 d9 2e 88 fb 03 aa ...`..t).H......
# 000005d0  07 97 4a 7f 6f f8 b3 4c 90 0d dc 79 5b d5 09 be ..J.o..L...y[...
# 000005e0  d3 23 4f 20 9d 5e c3 59 b7 b9 9d 5a be 6b cb 7b .#O .^.Y...Z.k.{
# 000005f0  0c 6b 51 d6 20 b7 09 12 26 78 95 bf 1f 0c 60 1c .kQ. ...&x....`.
# 00000600  1d 81 fa 48 ae 1d 83 71 66 c3 1d d6 b5 c6 79 02 ...H...qf.....y.
# 00000610  cf c2 a4 da c5 c1 05 20 21 51 0d c4 8f 67 4b 17 ....... !Q...gK.
# 00000620  28 7f 26 f5 39 35 5d 8b 75 f2 5f 1e 1e b7 ee 67 (.&.95].u._....g
# 00000630  eb 0b 8d a3 fb 50 17 0b 11 d2 8c 51 02 40 54 16 .....P.....Q.@T.
# 00000640  89 17 dc 26 32 9f f7 80 4e fd 01 d8 17 dc b3 a4 ...&2...N.......
# 00000650  d0 06 31 79 e3 58 67 06 ea f2 25 49 32 60 00 00 ..1y.Xg...%I2`..
# 00000660  01 b3 01 00 73 27 ed 5a 91 ef 53 3f 85 fd 97 53 ....s'.Z..S?...S
# 00000670  7c 9a 2a 29 4f 25 5d 84 6f 6a 6c 69 b3 37 9c a7 |.*)O%].ojli.7..
# 00000680  d4 5b 04 19 19 7e d8 4e 9c 1d 2d 8c b9 54 73 f3 .[...~.N..-..Ts.
# 00000690  01 3a 00 fe f6 0c ac 2e 89 ee 89 fa 73 61 1c 58 .:..........sa.X
# 000006a0  ec 22 31 5c 2d d4 7f e8 91 1b de 9c 1a bf 7a 62 ."1\-.........zb
# 000006b0  74 ed 28 a9 e7 2f 66 b7 e8 0f 31 b5 ce 3b 22 0c t.(../f...1..;".
# 000006c0  d6 83 22 62 19 63 25 80 ad e8 a9 ee 19 af b1 62 .."b.c%........b
# 000006d0  62 6e 07 1f c2 4f 76 70 41 a8 b7 0b fd 5d c1 f1 bn...OvpA....]..
# 000006e0  a6 3e 0b ad cf 4b 23 7e 3e aa 46 26 07 03 7a f3 .>...K#~>.F&..z.
# 000006f0  1c 79 22 31 e6 d4 08 ea 13 7a 51 0d 22 d7 cf 40 .y"1.....zQ."..@
# 00000700  b3 d0 0d be 9e 5c 01 53 c3 bb 01 4a b4 c1 f2 7e .....\.S...J...~
# 00000710  f8 e5 26 7b 4a 57 55 6b 89 48 e5 ba 04 cb 5f e6 ..&{JWUk.H...._.
# 00000720  8d 46 c3 e1 ea 64 1b f6 19 4d 43 59 af b0 8f 5a .F...d...MCY...Z
# 00000730  21 8a 23 8b 5a 7a 7c 50 9c 8c 3a ad 40 0a e8 cb !.#.Zz|P..:.@...
# 00000740  f9 3c 3e 66 86 b2 ae 76 ea 96 6d 33 df cb ff e6 .<>f...v..m3....
# 00000750  44 a2 39 6d d5 39 a0 96 b0 dd e0 d3 d1 10 6e a2 D.9m.9........n.
# 00000760  4c 59 f7 af 73 54 8a a7 d8 94 f7 83 5e 3d 3b 66 LY..sT......^=;f
# 00000770  34 6d 8a ae bf 2f 6d a9 7a 28 b3 ab 54 98 24 a5 4m.../m.z(..T.$.
# 00000780  57 f4 fa 4a 13 d6 f1 e4 c0 df c0 bb b6 51 f5 dc W..J.........Q..
# 00000790  0d 8e 04 8e a8 c9 7a 5d d4 47 76 8c 57 7f ec 76 ......z].Gv.W..v
# 000007a0  8b b2 41 1d b4 99 53 77 4e 02 29 26 87 05 bf ab ..A...SwN.)&....
# 000007b0  d2 48 1a 70 6e 38 35 bb 47 9a 94 94 71 6f a7 4e .H.pn85.G...qo.N
# 000007c0  5d 69 f1 01 d3 90 bb 1c 19 22 4b b4 e1 c5 70 09 ]i......."K...p.
# 000007d0  b5 5e d9 1c 12 f7 77 ef 14 1f 52 f7 51 2f 80 19 .^....w...R.Q/..
# 000007e0  22 ad 65 7c 33 c5 e7 1a fe 5f 89 ea c3 8a e8 8b ".e|3...._......
# 000007f0  d0 41 ae 88 9e 88 e1 4e 17 12 f5 37 bd 3c 09 e3 .A.....N...7.<..
# 00000800  56 58 ce 80 6a 27 58 d6 79 cb b3 aa dd 61 ea 2d VX..j'X.y....a.-
# 00000810  af 3d fd e6 e0                                  .=...
# [out_0_0 @ 0x5aae81aa5c80] EOF on sink link out_0_0:default.
# [h264 @ 0x5aae81865440] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 0
#     Last message repeated 3 times
# [out_0_1 @ 0x5aae819bc640] EOF on sink link out_0_1:default.
# No more output streams to write to, finishing.
# [libx264 @ 0x5aae817cf180] frame=  96 QP=23.68 NAL=2 Slice:B Poc:192 I:20   P:325  SKIP:855  size=1106 bytes
# [libx264 @ 0x5aae817cf180] frame=  97 QP=24.13 NAL=0 Slice:B Poc:190 I:15   P:200  SKIP:985  size=593 bytes
# [libx264 @ 0x5aae817cf180] frame=  98 QP=22.66 NAL=0 Slice:B Poc:194 I:11   P:303  SKIP:886  size=670 bytes
# [libx264 @ 0x5aae817cf180] frame=  99 QP=20.04 NAL=2 Slice:P Poc:204 I:358  P:454  SKIP:388  size=3242 bytes
# [libx264 @ 0x5aae817cf180] frame= 100 QP=20.96 NAL=2 Slice:B Poc:200 I:51   P:521  SKIP:628  size=1505 bytes
# [libx264 @ 0x5aae817cf180] frame= 101 QP=22.67 NAL=0 Slice:B Poc:198 I:8    P:261  SKIP:931  size=557 bytes
# [libx264 @ 0x5aae817cf180] frame= 102 QP=22.77 NAL=0 Slice:B Poc:202 I:2    P:254  SKIP:944  size=544 bytes
# [libx264 @ 0x5aae817cf180] frame= 103 QP=19.63 NAL=2 Slice:P Poc:212 I:275  P:406  SKIP:519  size=2986 bytes
# [libx264 @ 0x5aae817cf180] frame= 104 QP=22.20 NAL=2 Slice:B Poc:208 I:12   P:306  SKIP:882  size=879 bytes
# [libx264 @ 0x5aae817cf180] frame= 105 QP=23.89 NAL=0 Slice:B Poc:206 I:3    P:152  SKIP:1045 size=405 bytes
# [libx264 @ 0x5aae817cf180] frame= 106 QP=24.96 NAL=0 Slice:B Poc:210 I:7    P:125  SKIP:1068 size=362 bytes
# [libx264 @ 0x5aae817cf180] frame= 107 QP=19.59 NAL=2 Slice:P Poc:220 I:349  P:436  SKIP:415  size=3213 bytes
# [libx264 @ 0x5aae817cf180] frame= 108 QP=20.93 NAL=2 Slice:B Poc:216 I:32   P:357  SKIP:811  size=947 bytes
# [libx264 @ 0x5aae817cf180] frame= 109 QP=22.61 NAL=0 Slice:B Poc:214 I:4    P:230  SKIP:966  size=489 bytes
# [libx264 @ 0x5aae817cf180] frame= 110 QP=21.72 NAL=0 Slice:B Poc:218 I:4    P:142  SKIP:1054 size=299 bytes
# [libx264 @ 0x5aae817cf180] frame= 111 QP=20.92 NAL=2 Slice:P Poc:228 I:213  P:326  SKIP:661  size=1709 bytes
# [libx264 @ 0x5aae817cf180] frame= 112 QP=21.01 NAL=2 Slice:B Poc:224 I:17   P:237  SKIP:946  size=687 bytes
# [libx264 @ 0x5aae817cf180] frame= 113 QP=22.63 NAL=0 Slice:B Poc:222 I:2    P:138  SKIP:1060 size=330 bytes
# [libx264 @ 0x5aae817cf180] frame= 114 QP=22.83 NAL=0 Slice:B Poc:226 I:1    P:121  SKIP:1078 size=293 bytes
# [libx264 @ 0x5aae817cf180] frame= 115 QP=23.71 NAL=2 Slice:P Poc:230 I:23   P:137  SKIP:1040 size=464 bytes
# [aac @ 0x5aae817f4380] Trying to remove 888 more samples than there are in the queue
# frame=  116 fps= 13 q=-1.0 L10000000000000000000000000003000size=     218kB time=00:00:01.99 bitrate= 895.3kbits/s speed=0.217x
# video:182kB audio:31kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.197883%
# Input file #0 (/kaggle/input/testmp4/test.mp4):
#   Input stream #0:0 (video): 55 packets read (299141 bytes); 50 frames decoded;
#   Input stream #0:1 (audio): 95 packets read (34839 bytes); 94 frames decoded (96256 samples);
#   Total: 150 packets (333980 bytes) demuxed
# Output file #0 (/kaggle/working/output/test_60_short.mp4):
#   Output stream #0:0 (video): 116 frames encoded; 116 packets muxed (186732 bytes);
#   Output stream #0:1 (audio): 87 frames encoded (88200 samples); 88 packets muxed (31933 bytes);
#   Total: 204 packets (218665 bytes) muxed
# 144 frames successfully decoded, 0 decoding errors
# [AVIOContext @ 0x5aae81865d00] Statistics: 2 seeks, 4 writeouts
# [libx264 @ 0x5aae817cf180] frame I:1     Avg QP:19.82  size:  7580
# [libx264 @ 0x5aae817cf180] frame P:30    Avg QP:20.53  size:  3665
# [libx264 @ 0x5aae817cf180] frame B:85    Avg QP:23.05  size:   806
# [libx264 @ 0x5aae817cf180] consecutive B-frames:  1.7%  0.0%  5.2% 93.1%
# [libx264 @ 0x5aae817cf180] mb I  I16..4: 44.6% 43.8% 11.7%
# [libx264 @ 0x5aae817cf180] mb P  I16..4: 17.8% 13.8%  0.8%  P16..4: 21.5% 10.3%  3.8%  0.0%  0.0%    skip:32.0%
# [libx264 @ 0x5aae817cf180] mb B  I16..4:  1.1%  0.4%  0.0%  B16..8: 14.6%  3.0%  0.1%  direct: 5.3%  skip:75.5%  L0:33.5% L1:45.2% BI:21.3%
# [libx264 @ 0x5aae817cf180] 8x8 transform intra:41.0% inter:28.8%
# [libx264 @ 0x5aae817cf180] coded y,uvDC,uvAC intra: 22.1% 51.6% 13.2% inter: 2.1% 12.1% 0.3%
# [libx264 @ 0x5aae817cf180] i16 v,h,dc,p: 55% 30%  7%  8%
# [libx264 @ 0x5aae817cf180] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 50% 22%  1%  2%  2%  3%  1%  1%
# [libx264 @ 0x5aae817cf180] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 46% 11%  4%  5%  6%  5%  5%  3%
# [libx264 @ 0x5aae817cf180] i8c dc,h,v,p: 48% 29% 17%  5%
# [libx264 @ 0x5aae817cf180] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5aae817cf180] kb/s:769.84
# [aac @ 0x5aae817f4380] Qavg: 919.569
# [AVIOContext @ 0x5aae817ab600] Statistics: 360448 bytes read, 0 seeks
# bash: line 5: syntax error near unexpected token `||'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_37/823175832.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'set -e\necho \'Smoke-test: 2s minterpolate -> /kaggle/working/output/test_60_short.mp4\'\nmkdir -p /kaggle/working/output\nffmpeg -y -t 2 -i /kaggle/input/testmp4/test.mp4 -vf "minterpolate=mi_mode=mci:mc_mode=aobmc:vsbmc=1:fps=60" -c:v libx264 -preset veryfast -crf 20 /kaggle/working/output/test_60_short.mp4\nls -lh /kaggle/working/output/test_60_short.mp4 || true\n')
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'set -e\necho \'Smoke-test: 2s minterpolate -> /kaggle/working/output/test_60_short.mp4\'\nmkdir -p /kaggle/working/output\nffmpeg -y -t 2 -i /kaggle/input/testmp4/test.mp4 -vf "minterpolate=mi_mode=mci:mc_mode=aobmc:vsbmc=1:fps=60" -c:v libx264 -preset veryfast -crf 20 /kaggle/working/output/test_60_short.mp4\nls -lh /kaggle/working/output/test_60_short.mp4 || true\n'' returned non-zero exit status 2.

# %% [markdown]
# ## RIFE (опционально) — DL-интерполяция
# Если хотите лучшее качество, запустите RIFE. Требует веса модели и GPU.

# %%
# %%bash
# set -e
# if [ ! -d /kaggle/working/arXiv2019-RIFE ]; then
#   git clone https://github.com/hzwer/arXiv2019-RIFE.git /kaggle/working/arXiv2019-RIFE
# fi
# pip install -q -r /kaggle/working/arXiv2019-RIFE/requirements.txt || true
# echo 'Upload RIFE weights into /kaggle/working/arXiv2019-RIFE/train_log per repo README'
# if [ -f /kaggle/working/arXiv2019-RIFE/inference_video.py ]; then
#   python /kaggle/working/arXiv2019-RIFE/inference_video.py --exp=slomo --video /kaggle/working/input/dn.mp4 --output /kaggle/working/output/dn_60fps_rife.mp4 --fp16 || true
# else
#   echo 'RIFE script not found' >&2
# fi
# ls -lh /kaggle/working/output || true

# %% [markdown]
# ## Real-ESRGAN (апскейл) — опционально
# Пример: извлечь кадры из 60fps видео, апскейлить и собрать обратно.

# %%
# %%bash
# set -e
# if [ ! -d /kaggle/working/Real-ESRGAN ]; then
#   git clone https://github.com/xinntao/Real-ESRGAN.git /kaggle/working/Real-ESRGAN
# fi
# pip install -q -r /kaggle/working/Real-ESRGAN/requirements.txt || true
# mkdir -p /kaggle/working/frames /kaggle/working/upscaled_frames
# if [ ! -f /kaggle/working/output/dn_60fps_rife.mp4 ]; then echo 'Put 60fps RIFE output in /kaggle/working/output/' >&2; fi
# ffmpeg -y -i /kaggle/working/output/dn_60fps_rife.mp4 -vsync 0 /kaggle/working/frames/frame_%08d.png || true
# python /kaggle/working/Real-ESRGAN/inference_realesrgan.py --input /kaggle/working/frames --output /kaggle/working/upscaled_frames --model RealESRGAN_x4plus --tile 400 --tile_pad 10 --fp16 || true
# ffmpeg -y -framerate 60 -i /kaggle/working/upscaled_frames/frame_%08d_up.png -c:v libx264 -pix_fmt yuv420p /kaggle/working/output/dn_60fps_4k_noaudio.mp4 || true
# ffmpeg -y -i /kaggle/working/output/dn_60fps_4k_noaudio.mp4 -i /kaggle/working/input/dn.mp4 -c copy -map 0:v:0 -map 1:a:0 /kaggle/working/output/dn_60fps_4k_with_audio.mp4 || true
# ls -lh /kaggle/working/output || true

# %% [markdown]
# ### Команды для Windows (локально)
# Примеры: ремукс, smoke‑тест и полная конвертация в 60fps (ffmpeg).

# %%
# Локальные команды:
# cd /d D:\PHPStormProjects\interup
# ffprobe -v quiet -print_format json -show_format -show_streams dn.mp4
# ffmpeg -y -t 2 -i "dn.mp4" -vf "minterpolate=mi_mode=mci:mc_mode=aobmc:vsbmc=1:fps=60" -c:v libx264 -preset veryfast -crf 20 dn_60_short.mp4
print('See markdown cell for Windows commands')
